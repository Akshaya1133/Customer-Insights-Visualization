# %%
#importing libary
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#uploading Mall_Customers csv file
df = pd.read_csv("Mall_Customers.csv")

# %%
#to check how many rows and columns
df.shape
# Out:
# (200, 5)

# %%
#printing first 5 values from Mall_Customers csv file
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#describing each rows 
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
#feature names
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
#data type of each feature
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
#checking null values
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
#Distplot for ['Age', 'Annual Income (k$)','Spending Score (1-100)']:
plt.figure(1, figsize=(15,6))
n=0
for x in ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']:
    n+=1
    plt.subplot(1,3,n)
    plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
    sns.histplot(df[x], bins=20, kde=True)
    plt.title('Distribution of {}'.format(x))
plt.show()

# %%
#count of gender which buys more
plt.figure(figsize =(15,5))
sns.countplot(y = 'Gender', data = df)
plt.title('Count of Gender')
plt.show()

# %%
#dividing numbers of customers by age group
age_18_24 = df.Age[(df.Age>= 18) & (df.Age <= 24)]
age_25_34 = df.Age[(df.Age >= 25) & (df.Age <= 34)]
age_35_44 = df.Age[(df.Age >= 35) & (df.Age <= 44)]
age_45_54 = df.Age[(df.Age >= 45) & (df.Age <= 54)]
age_54above = df.Age[df.Age >= 55]

agex = ["18-24", "25-34", "35-44", "45-54", "54+"]
agey = [len(age_18_24.values), len(age_25_34.values), len(age_35_44.values), len(age_45_54.values), len(age_54above.values)]

#graph plotting
plt.figure(figsize = (15,6))
sns.barplot(x = agex, y = agey, palette = "mako")
plt.title("Number of customers by age group")
plt.xlabel("Age Group")
plt.ylabel("Number of Customers")
plt.show()

# %%
#Relationship between 'Annual Income (k$)' and 'Spending Score (1-100)'
sns.relplot(x = "Annual Income (k$)", y = "Spending Score (1-100)", data = df)
plt.title('Annual Income vs. Spending Score')
plt.show()

# %%
#Dividing customers by spending score ranges
ss_1_20 = df["Spending Score (1-100)"][(df["Spending Score (1-100)"] >= 1) & (df["Spending Score (1-100)"] <= 20)]
ss_21_40 = df["Spending Score (1-100)"][(df["Spending Score (1-100)"] >= 21) & (df["Spending Score (1-100)"] <= 40)]
ss_41_60 = df["Spending Score (1-100)"][(df["Spending Score (1-100)"] >= 41) & (df["Spending Score (1-100)"] <= 60)]
ss_61_80 = df["Spending Score (1-100)"][(df["Spending Score (1-100)"] >= 61) & (df["Spending Score (1-100)"] <= 80)]
ss_81_100 = df["Spending Score (1-100)"][(df["Spending Score (1-100)"] >= 81) & (df["Spending Score (1-100)"] <= 100)]

ssx = ["1-20", "21-40", "41-60", "61-80", "81-100"]
ssy = [len(ss_1_20.values), len(ss_21_40.values), len(ss_41_60.values), len(ss_61_80.values), len(ss_81_100.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=ssx, y=ssy)
plt.title("Spending Score Distribution")
plt.xlabel("Spending Score Range")
plt.ylabel("Number of Customers")
plt.show()

#Dividing customers by annual income ranges
ai0_30 = df["Annual Income (k$)"][(df["Annual Income (k$)"] >=0) & (df["Annual Income (k$)"]<=30)]
ai31_60 = df["Annual Income (k$)"][(df["Annual Income (k$)"] >=31) & (df["Annual Income (k$)"]<=60)]
ai61_90 = df["Annual Income (k$)"][(df["Annual Income (k$)"] >=61) & (df["Annual Income (k$)"]<=90)]
ai91_120 = df["Annual Income (k$)"][(df["Annual Income (k$)"] >=91) & (df["Annual Income (k$)"]<=120)]
ai121_150 = df["Annual Income (k$)"][(df["Annual Income (k$)"] >=121) & (df["Annual Income (k$)"]<=150)]

aix = ["$ 0-30,000", "$ 30,001-60,000", "$ 60,001-90,000", "$ 90,001-120,000", "$ 120,001-150,000"]
aiy = [len(ai0_30.values), len(ai31_60.values), len(ai61_90.values), len(ai91_120.values), len(ai121_150.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=aix, y=aiy)
plt.title("Annual Income Distribution")
plt.xlabel("Annual Income Range")
plt.ylabel("Number of Customers")
plt.show()
